# %% [markdown]
# MARKET POTENTIAL

# %%
import openrouteservice
from ipyleaflet import Map, basemaps, Marker,AwesomeIcon

icon = AwesomeIcon(
    name='flag',
    marker_color='green',
    icon_color='white'
)

center = [60.14970818552943, 10.722651452185813]
zoom = 11
marker = Marker(location=center, draggable=True,icon=icon)
m=Map(basemap=basemaps.OpenStreetMap.Mapnik, center=center, zoom=zoom)
m.add(marker)
display(m)
# Out:
# Map(center=[60.14970818552943, 10.722651452185813], controls=(ZoomControl(options=['position', 'zoom_in_text',…

# %%
print(marker.location)
coordinate=[marker.location[1],marker.location[0]]
# Out:
# [60.13466696253271, 11.169663219470372]

# %%
import features
from ipyleaflet import GeoJSON

iso=features.get_isochrone_time(marker.location[1],marker.location[0],10)
addresses=features.get_addresses_from_osm_for_isochrone(iso)
isochrone_layer = GeoJSON(data=iso, style={"color": "green"})
subsampled=features.subsample_addresses(addresses,50)

addres_layer =GeoJSON(data=features.gdf_to_geojson(subsampled),point_style={
        "radius": 8,           # circle size
        "color": "blue",       # outline color
        "fillColor": "yellow", # fill color
        "fillOpacity": 0.8,    # transparency
        "weight": 2            # outline width
    },)
route=features.get_route(subsampled)
route_layer =GeoJSON(data=route,style={"color": "red"})

m.add(isochrone_layer)
m.add(addres_layer)
m.add(route_layer)
# Out:
# Map(bottom=152016.0, center=[60.14970818552943, 10.722651452185813], controls=(ZoomControl(options=['position'…
